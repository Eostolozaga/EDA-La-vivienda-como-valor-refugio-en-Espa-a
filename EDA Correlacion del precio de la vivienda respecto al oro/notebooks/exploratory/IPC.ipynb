# %%
import pandas as pd
IPC = pd.DataFrame(pd.read_csv(r"C:\Users\Eneko\Desktop\Ejercicios Data\Ejercicios\Proyecto EDA\EDA Correlacion del precio de la vivienda respecto al oro\CSV\IPC INE PowerBI Modificado.csv")) # Corregido con PowerBI
fuente = "https://www.ine.es/dyngs/INEbase/es/operacion.htm?c=Estadistica_C&cid=1254736152838&menu=ultiDatos&idp=1254735976607"

# %%
IPC.head() # Cambio de formato fecha en PowerBI. Exportado a excel para poder guardarlo como csv
# Out:
#    PERIODO VALOR
# 0  2026-02   0,4
# 1  2026-01  -0,4
# 2  2025-12   0,3
# 3  2025-11   0,2
# 4  2025-10   0,7

# %%
#IPC.to_csv('IPC_limpio.csv', index=False)

# %%
# Renombrar la columna de fecha a un nombre estándar (ej. 'fecha')
# Sustituye 'Nombre_Actual' por el nombre que tenga ahora esa columna
IPC =IPC.rename(columns={'PERIODO': 'DateTime'})

# Convertir esa columna a formato datetime
IPC['DateTime'] = pd.to_datetime(IPC['DateTime'])

# Crear la columna 'Anio' extrayendo el año del datetime
IPC['Anio'] = IPC['DateTime'].dt.year

# Sobrescribir el CSV original con los cambios
# Usamos index=False para que no te cree una columna de números extra
IPC.to_csv('IPC_final.csv', index=False)

print("¡Archivo actualizado correctamente con la columna Anio!")
# Out:
# ¡Archivo actualizado correctamente con la columna Anio!
